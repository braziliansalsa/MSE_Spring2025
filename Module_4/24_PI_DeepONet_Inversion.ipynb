# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeiVKalinin/MSE_Spring2025/blob/main/Module_4/24_PI_DeepONet_Inversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Physics Informed Deep Neural Operators
# - Based on: https://towardsdatascience.com/operator-learning-via-physics-informed-deeponet-lets-implement-it-from-scratch-6659f3179887/
# - Code at: https://github.com/ShuaiGuo16/PI-DeepONet/tree/main

# %% [markdown]
# ### Objective
#
# In this notebook, we develop a PI-DeepONet model that tackles inverse problems. Specifically, we investigate the following example equation:
#
# \begin{equation}
# \frac{ds(t)}{dt} = 0.5 \cdot u(t) + 0.5, \; t \in [0, 1]
# \end{equation}
#
# with an initial condition $s(0)=0$. Our goal is to calibrate u(t) given the observed s(t).

# %% [markdown]
# ### 0. Import libraries

# %%
# !pip install keras==2.14.0 tensorflow==2.14.0
# Out:
# Collecting keras==2.14.0
#   Downloading keras-2.14.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting tensorflow==2.14.0
#   Downloading tensorflow-2.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (18.1.1)
# Collecting ml-dtypes==0.2.0 (from tensorflow==2.14.0)
#   Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.14.0)
#   Downloading wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0) (1.70.0)
# Collecting tensorboard<2.15,>=2.14 (from tensorflow==2.14.0)
#   Downloading tensorboard-2.14.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow==2.14.0)
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.14.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.38.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.15,>=2.14->tensorflow==2.14.0)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.2.2)
# Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.8 MB/s eta 0:00:00
# Downloading tensorflow-2.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.9/489.9 MB 1.2 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.9 MB/s eta 0:00:00
# Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 93.8 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 24.8 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 5.6 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.8.0
#     Uninstalling keras-3.8.0:
#       Successfully uninstalled keras-3.8.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.18.0
#     Uninstalling tensorflow-2.18.0:
#       Successfully uninstalled tensorflow-2.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.14.0 which is incompatible.
# tensorstore 0.1.72 requires ml_dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.14.0 which is incompatible.
# Successfully installed google-auth-oauthlib-1.0.0 keras-2.14.0 ml-dtypes-0.2.0 tensorboard-2.14.1 tensorflow-2.14.0 tensorflow-estimator-2.14.0 wrapt-1.14.1

# %%
# Common packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from collections import defaultdict
from tqdm import tqdm
import time

import tensorflow as tf
from tensorflow import keras
tf.random.set_seed(42)

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.integrate import solve_ivp

from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# ### 1. Data generation
#
# We use a zero-mean Gaussian Process to generate the dataset for both training and testing.

# %%
def create_samples(length_scale, sample_num):
    """Create synthetic data for u(·)

    Args:
    ----
    length_scale: float, length scale for RNF kernel
    sample_num: number of u(·) profiles to generate

    Outputs:
    --------
    u_sample: generated u(·) profiles
    """

    # Define kernel with given length scale
    kernel = RBF(length_scale)

    # Create Gaussian process regressor
    gp = GaussianProcessRegressor(kernel=kernel)

    # collocation point locations
    X_sample = np.linspace(0, 1, 100).reshape(-1, 1)

    # create samples
    u_sample = np.zeros((sample_num, 100))
    for i in range(sample_num):
        n = np.random.randint(0, 10000)
        u_sample[i, :] = gp.sample_y(X_sample, random_state=n).flatten()  # sampling from the prior

    return u_sample

# %%
# Inspect generated data
length_scale = 0.4
N = 20
X_sample = np.linspace(0, 1, 100).reshape(-1, 1)
y_sample = create_samples(length_scale, N)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
index = np.random.choice(np.arange(0, N), size=4, replace=False)
for i in range(4):
    ax = axs[i // 2, i % 2]
    ax.plot(X_sample, y_sample[index[i]])

# %% [markdown]
# ### 2. Organize dataset for PI-DeepONet

# %%
def generate_dataset(N, length_scale, a, b, ODE_solve=False):
    """Generate dataset for Physics-informed DeepONet training.

    Args:
    ----
    N: int, number of u(·) profiles
    length_scale: float, length scale for RNF kernel
    a, b: unknown ODE parameters that need to be calibrated
    ODE_solve: boolean, indicate whether to compute the corresponding s(·)

    Outputs:
    --------
    X: the dataset for t, u(·) profiles, and u(t)
    y: the dataset for the corresponding ODE solution s(·)
    """

    # Create random fields
    random_field = create_samples(length_scale, N)

    # Compile dataset
    X = np.zeros((N*100, 100+2))
    y = np.zeros((N*100, 1))

    for i in tqdm(range(N)):
        u = np.tile(random_field[i, :], (100, 1))
        t = np.linspace(0, 1, 100).reshape(-1, 1)

        # u(·) evaluated at t
        u_t = np.diag(u).reshape(-1, 1)

        # Update overall matrix
        X[i*100:(i+1)*100, :] = np.concatenate((t, u, u_t), axis=1)

        # Solve ODE
        if ODE_solve:
            sol = solve_ivp(lambda var_t, var_s: a*np.interp(var_t, t.flatten(), random_field[i, :])+b,
                            t_span=[0, 1], y0=[0], t_eval=t.flatten(), method='RK45')
            y[i*100:(i+1)*100, :] = sol.y[0].reshape(-1, 1)

    return X, y

# %%
# Define true parameter values
a, b = 0.5, 0.5

# Create training dataset
N_train = 2000
length_scale_train = 0.4
X_train, y_train = generate_dataset(N_train, length_scale_train, a, b, ODE_solve=True)

# Create validation dataset
N_val = 100
length_scale_test = 0.4
X_val, y_val = generate_dataset(N_val, length_scale_test, a, b, ODE_solve=True)

# Create testing dataset
N_test = 100
length_scale_test = 0.4
X_forward_test, y_forward_test = generate_dataset(N_test, length_scale_test, a, b, ODE_solve=True)
X_inverse_test, y_inverse_test = generate_dataset(N_test, length_scale_test, a, b, ODE_solve=True)
# Out:
# 100%|██████████| 2000/2000 [00:03<00:00, 637.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 538.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 525.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 516.53it/s]

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4))
index = 25
ax[0].plot(np.linspace(0, 1, 100), X_forward_test[index*100, 1:-1], lw=4)
ax[0].set_xlabel('t', fontsize=14)
ax[0].set_ylabel('u(t)', fontsize=14)
ax[0].tick_params(axis='both', which='major', labelsize=12)
ax[0].grid(True)

ax[1].plot(np.linspace(0, 1, 100), y_forward_test[index*100:(index+1)*100], lw=4)
ax[1].set_xlabel('t', fontsize=14)
ax[1].set_ylabel('s(t)', fontsize=14)
ax[1].tick_params(axis='both', which='major', labelsize=12)
ax[1].grid(True)

# %% [markdown]
# #### Separate initial condition and collocation points

# %%
# Determine batch size
ini_batch_size = int(2000/100)
col_batch_size = 2000

# Create dataset object (initial conditions)
X_train_ini = tf.convert_to_tensor(X_train[X_train[:, 0]==0], dtype=tf.float32)
y_train_ini = tf.convert_to_tensor(y_train[X_train[:, 0]==0], dtype=tf.float32)
ini_ds = tf.data.Dataset.from_tensor_slices((X_train_ini, y_train_ini))
ini_ds = ini_ds.shuffle(5000).batch(ini_batch_size)


# Create dataset object (collocation points)
X_train = tf.convert_to_tensor(X_train, dtype=tf.float32)
y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.shuffle(100000).batch(col_batch_size)

# Data type conversion
X_val = tf.convert_to_tensor(X_val, dtype=tf.float32)
y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)

# Scaling
mean = {
    'forcing': np.mean(X_train[:, 1:-1], axis=0),
    'time': np.mean(X_train[:, :1], axis=0)
}

var = {
    'forcing': np.var(X_train[:, 1:-1], axis=0),
    'time': np.var(X_train[:, :1], axis=0)
}

# %% [markdown]
# ### 3. Physics-informed DeepONet

# %% [markdown]
# #### Define a custom layer for adding a bias

# %%
class BiasLayer(tf.keras.layers.Layer):
    def build(self, input_shape):
        self.bias = self.add_weight(shape=(1,),
                                    initializer=tf.keras.initializers.Zeros(),
                                    trainable=True)
    def call(self, inputs):
        return inputs + self.bias

# %% [markdown]
# #### Define a custom layer for hosting unknown parameters

# %%
class ParameterLayer(tf.keras.layers.Layer):
    def __init__(self, a, b, trainable=True):
        super(ParameterLayer, self).__init__()
        self._a = tf.convert_to_tensor(a, dtype=tf.float32)
        self._b = tf.convert_to_tensor(b, dtype=tf.float32)
        self.trainable = trainable

    def build(self, input_shape):
        self.a = self.add_weight("a", shape=(1,),
                                 initializer=tf.keras.initializers.Constant(value=self._a),
                                 trainable=self.trainable)
        self.b = self.add_weight("b", shape=(1,),
                                 initializer=tf.keras.initializers.Constant(value=self._b),
                                 trainable=self.trainable)

    def get_config(self):
        return super().get_config()

    @classmethod
    def from_config(cls, config):
        return cls(**config)

# %% [markdown]
# #### Define Physics-informed DeepONet

# %%
def create_model(mean, var, a_init=None, b_init=None, trainable=None, verbose=False):
    """Definition of a DeepONet with fully connected branch and trunk layers.

    Args:
    ----
    mean: dictionary, mean values of the inputs
    var: dictionary, variance values of the inputs
    verbose: boolean, indicate whether to show the model summary

    Outputs:
    --------
    model: the DeepONet model
    """

    # Branch net
    branch_input = tf.keras.Input(shape=(len(mean['forcing'])), name="forcing")
    branch = tf.keras.layers.Normalization(mean=mean['forcing'], variance=var['forcing'])(branch_input)
    for i in range(3):
        branch = tf.keras.layers.Dense(50, activation="tanh")(branch)

    # Trunk net
    trunk_input = tf.keras.Input(shape=(len(mean['time'])), name="time")
    trunk = tf.keras.layers.Normalization(mean=mean['time'], variance=var['time'])(trunk_input)
    for i in range(3):
        trunk = tf.keras.layers.Dense(50, activation="tanh")(trunk)

    # Compute the dot product between branch and trunk net
    dot_product = tf.reduce_sum(tf.multiply(branch, trunk), axis=1, keepdims=True)

    # Add the bias
    dot_product_with_bias = BiasLayer()(dot_product)

    # Add a & b trainable parameters
    output = ParameterLayer(a_init, b_init, trainable)(dot_product_with_bias)

    # Create the model
    model = tf.keras.models.Model(inputs=[branch_input, trunk_input], outputs=output)

    if verbose:
        model.summary()

    return model

# %% [markdown]
# #### ODE loss

# %%
@tf.function
def ODE_residual_calculator(t, u, u_t, model):
    """ODE residual calculation.

    Args:
    ----
    t: temporal coordinate
    u: input function evaluated at discrete temporal coordinates
    u_t: input function evaluated at t
    model: DeepONet model

    Outputs:
    --------
    ODE_residual: residual of the governing ODE
    """

    with tf.GradientTape() as tape:
        tape.watch(t)
        s = model({"forcing": u, "time": t})

    # Calculate gradients
    ds_dt = tape.gradient(s, t)

    # ODE residual
    ODE_residual = ds_dt - model.layers[-1].a*u_t - model.layers[-1].b

    return ODE_residual

# %% [markdown]
# #### Gradient descent step

# %%
@tf.function
def train_step(X, y, X_init, IC_weight, ODE_weight, data_weight, model):
    """Calculate gradients of the total loss with respect to network model parameters.

    Args:
    ----
    X: training dataset for evaluating ODE residuals
    X_init: training dataset for evaluating initial conditions
    IC_weight: weight for initial condition loss
    ODE_weight: weight for ODE loss
    model: DeepONet model

    Outputs:
    --------
    ODE_loss: calculated ODE loss
    IC_loss: calculated initial condition loss
    total_loss: weighted sum of ODE loss and initial condition loss
    gradients: gradients of the total loss with respect to network model parameters.
    """
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_weights)

        # Initial condition prediction
        y_pred_IC = model({"forcing": X_init[:, 1:-1], "time": X_init[:, :1]})

        # Equation residual
        ODE_residual = ODE_residual_calculator(t=X[:, :1], u=X[:, 1:-1], u_t=X[:, -1:], model=model)

        # Data loss
        y_pred_data = model({"forcing": X[:, 1:-1], "time": X[:, :1]})

        # Calculate loss
        IC_loss = tf.reduce_mean(keras.losses.mean_squared_error(0, y_pred_IC))
        ODE_loss = tf.reduce_mean(tf.square(ODE_residual))
        data_loss = tf.reduce_mean(keras.losses.mean_squared_error(y, y_pred_data))

        # Weight loss
        total_loss = IC_loss*IC_weight + ODE_loss*ODE_weight + data_loss*data_weight

    gradients = tape.gradient(total_loss, model.trainable_variables)

    return ODE_loss, IC_loss, data_loss, total_loss, gradients

# %% [markdown]
# #### Define Loss Tracking class

# %%
class LossTracking:

    def __init__(self):
        self.mean_total_loss = keras.metrics.Mean()
        self.mean_IC_loss = keras.metrics.Mean()
        self.mean_ODE_loss = keras.metrics.Mean()
        self.mean_data_loss = keras.metrics.Mean()
        self.loss_history = defaultdict(list)

    def update(self, total_loss, IC_loss, ODE_loss, data_loss):
        self.mean_total_loss(total_loss)
        self.mean_IC_loss(IC_loss)
        self.mean_ODE_loss(ODE_loss)
        self.mean_data_loss(data_loss)

    def reset(self):
        self.mean_total_loss.reset_states()
        self.mean_IC_loss.reset_states()
        self.mean_ODE_loss.reset_states()
        self.mean_data_loss.reset_states()

    def print(self):
        print(f"IC={self.mean_IC_loss.result().numpy():.4e}, \
              ODE={self.mean_ODE_loss.result().numpy():.4e}, \
              data={self.mean_data_loss.result().numpy():.4e}, \
              total_loss={self.mean_total_loss.result().numpy():.4e}")

    def history(self):
        self.loss_history['total_loss'].append(self.mean_total_loss.result().numpy())
        self.loss_history['IC_loss'].append(self.mean_IC_loss.result().numpy())
        self.loss_history['ODE_loss'].append(self.mean_ODE_loss.result().numpy())
        self.loss_history['Data_loss'].append(self.mean_data_loss.result().numpy())

# %% [markdown]
# #### Define callback

# %%
class PrintParameters(keras.callbacks.Callback):

    def on_epoch_end(self, epoch, logs=None):
        print(f"\na: {self.model.layers[-1].a.numpy()}, b: {self.model.layers[-1].b.numpy()}")

# %% [markdown]
# #### Training: create the surrogate model

# %%
# Set up training configurations
n_epochs = 200
IC_weight= tf.constant(1.0, dtype=tf.float32)
ODE_weight= tf.constant(1.0, dtype=tf.float32)
data_weight= tf.constant(0.0, dtype=tf.float32)
loss_tracker = LossTracking()
val_loss_hist = []
a_list, b_list = [], []

# True values for unknown parameters
a, b = 0.5, 0.5

# Set up optimizer
optimizer = keras.optimizers.Adam(learning_rate=1e-3)

with tf.device("CPU:0"):

    # Instantiate the PINN model
    PI_DeepONet = create_model(mean, var, a_init=a, b_init=b, trainable=False)
    PI_DeepONet.compile(optimizer=optimizer)

    # Configure callbacks
    _callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=30),
                 tf.keras.callbacks.ModelCheckpoint('NN_model.h5', monitor='val_loss', save_best_only=True),
                 PrintParameters()]
    callbacks = tf.keras.callbacks.CallbackList(
                    _callbacks, add_history=False, model=PI_DeepONet)

    # Start training process
    for epoch in range(1, n_epochs + 1):
        print(f"Epoch {epoch}:")

        for (X_init, _), (X, y) in zip(ini_ds, train_ds):

            # Calculate gradients
            ODE_loss, IC_loss, data_loss, total_loss, gradients = train_step(X, y, X_init,
                                                                            IC_weight, ODE_weight,
                                                                            data_weight, PI_DeepONet)
            # Gradient descent
            PI_DeepONet.optimizer.apply_gradients(zip(gradients, PI_DeepONet.trainable_variables))


            # Loss tracking
            loss_tracker.update(total_loss, IC_loss, ODE_loss, data_loss)

        # Loss summary
        loss_tracker.history()
        loss_tracker.print()
        loss_tracker.reset()

        # Parameter recording
        a_list.append(PI_DeepONet.layers[-1].a.numpy())
        b_list.append(PI_DeepONet.layers[-1].b.numpy())

        ####### Validation
        val_res = ODE_residual_calculator(X_val[:, :1], X_val[:, 1:-1], X_val[:, -1:], PI_DeepONet)
        val_ODE = tf.cast(tf.reduce_mean(tf.square(val_res)), tf.float32)

        X_val_ini = X_val[X_val[:, 0]==0]
        pred_ini_valid = PI_DeepONet.predict({"forcing": X_val_ini[:, 1:-1], "time": X_val_ini[:, :1]}, batch_size=12800)
        val_IC = tf.reduce_mean(keras.losses.mean_squared_error(0, pred_ini_valid))
        print(f"val_IC: {val_IC.numpy():.4e}, val_ODE: {val_ODE.numpy():.4e}, lr: {PI_DeepONet.optimizer.lr.numpy():.2e}")

        # Callback at the end of epoch
        callbacks.on_epoch_end(epoch, logs={'val_loss': val_ODE+val_IC})
        val_loss_hist.append(val_ODE+val_IC)


        # Re-shuffle dataset
        ini_ds = tf.data.Dataset.from_tensor_slices((X_train_ini, y_train_ini))
        ini_ds = ini_ds.shuffle(5000).batch(ini_batch_size)

        train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
        train_ds = train_ds.shuffle(100000).batch(col_batch_size)
# Out:
# Epoch 1:
# IC=5.3088e-02,               ODE=1.9659e-01,               data=5.4964e-02,               total_loss=2.4968e-01
# 1/1 [==============================] - 0s 141ms/step
# val_IC: 3.4787e-03, val_ODE: 2.7264e-02, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 2:
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# IC=1.5977e-03,               ODE=1.7072e-02,               data=3.1663e-03,               total_loss=1.8669e-02
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 9.9791e-04, val_ODE: 1.3048e-02, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 3:
# IC=9.7607e-04,               ODE=9.9040e-03,               data=1.7457e-03,               total_loss=1.0880e-02
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 7.8128e-04, val_ODE: 9.0333e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 4:
# IC=7.3788e-04,               ODE=7.6231e-03,               data=1.2574e-03,               total_loss=8.3610e-03
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 5.6573e-04, val_ODE: 7.2108e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 5:
# IC=5.7964e-04,               ODE=6.1995e-03,               data=9.6157e-04,               total_loss=6.7792e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 5.1364e-04, val_ODE: 5.7637e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 6:
# IC=4.7257e-04,               ODE=5.1611e-03,               data=7.6521e-04,               total_loss=5.6337e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 4.4147e-04, val_ODE: 4.8467e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 7:
# IC=3.9548e-04,               ODE=4.4080e-03,               data=6.0641e-04,               total_loss=4.8035e-03
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 3.1832e-04, val_ODE: 4.2446e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 8:
# IC=3.0464e-04,               ODE=3.8268e-03,               data=4.8209e-04,               total_loss=4.1314e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 2.2713e-04, val_ODE: 3.6549e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 9:
# IC=2.3919e-04,               ODE=3.3636e-03,               data=3.8853e-04,               total_loss=3.6028e-03
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 1.9273e-04, val_ODE: 3.2496e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 10:
# IC=1.8539e-04,               ODE=3.0297e-03,               data=3.2502e-04,               total_loss=3.2151e-03
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 1.9237e-04, val_ODE: 2.9473e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 11:
# IC=1.6939e-04,               ODE=2.7678e-03,               data=2.9105e-04,               total_loss=2.9372e-03
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.3663e-04, val_ODE: 2.7170e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 12:
# IC=1.4008e-04,               ODE=2.5386e-03,               data=2.4213e-04,               total_loss=2.6787e-03
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.5497e-04, val_ODE: 2.5442e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 13:
# IC=1.2368e-04,               ODE=2.3303e-03,               data=2.1733e-04,               total_loss=2.4539e-03
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.0924e-04, val_ODE: 2.2904e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 14:
# IC=1.1000e-04,               ODE=2.1530e-03,               data=1.9740e-04,               total_loss=2.2630e-03
# 1/1 [==============================] - 0s 35ms/step
# val_IC: 1.2948e-04, val_ODE: 2.1320e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 15:
# IC=1.0575e-04,               ODE=1.9883e-03,               data=1.8478e-04,               total_loss=2.0940e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.0660e-04, val_ODE: 1.9557e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 16:
# IC=9.5748e-05,               ODE=1.7758e-03,               data=1.7374e-04,               total_loss=1.8716e-03
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 1.0116e-04, val_ODE: 1.7269e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 17:
# IC=9.9709e-05,               ODE=1.5780e-03,               data=1.7162e-04,               total_loss=1.6777e-03
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 8.4008e-05, val_ODE: 1.5211e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 18:
# IC=8.6359e-05,               ODE=1.3573e-03,               data=1.5162e-04,               total_loss=1.4437e-03
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 9.7740e-05, val_ODE: 1.3261e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 19:
# IC=8.1526e-05,               ODE=1.1481e-03,               data=1.5184e-04,               total_loss=1.2296e-03
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 6.6162e-05, val_ODE: 1.1384e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 20:
# IC=7.7899e-05,               ODE=9.7310e-04,               data=1.3665e-04,               total_loss=1.0510e-03
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 5.7616e-05, val_ODE: 9.4460e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 21:
# IC=7.3008e-05,               ODE=8.3426e-04,               data=1.2768e-04,               total_loss=9.0727e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 7.9910e-05, val_ODE: 1.0132e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 22:
# IC=6.6005e-05,               ODE=7.6531e-04,               data=1.2474e-04,               total_loss=8.3131e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 7.7376e-05, val_ODE: 8.9549e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 23:
# IC=6.5215e-05,               ODE=6.9875e-04,               data=1.1582e-04,               total_loss=7.6396e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 8.7602e-05, val_ODE: 7.8281e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 24:
# IC=5.5052e-05,               ODE=6.7863e-04,               data=1.0702e-04,               total_loss=7.3368e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 4.1549e-05, val_ODE: 7.2233e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 25:
# IC=5.8586e-05,               ODE=6.9047e-04,               data=1.0476e-04,               total_loss=7.4905e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 5.0855e-05, val_ODE: 6.6698e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 26:
# IC=4.9040e-05,               ODE=5.9881e-04,               data=9.1206e-05,               total_loss=6.4785e-04
# 1/1 [==============================] - 0s 36ms/step
# val_IC: 7.0711e-05, val_ODE: 7.8256e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 27:
# IC=4.6700e-05,               ODE=6.1006e-04,               data=8.9243e-05,               total_loss=6.5676e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 3.0593e-05, val_ODE: 5.8796e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 28:
# IC=4.0987e-05,               ODE=5.4325e-04,               data=7.8999e-05,               total_loss=5.8424e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 2.8698e-05, val_ODE: 5.5945e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 29:
# IC=4.2405e-05,               ODE=5.3623e-04,               data=8.0007e-05,               total_loss=5.7863e-04
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 5.7613e-05, val_ODE: 7.0366e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 30:
# IC=4.2139e-05,               ODE=5.5022e-04,               data=8.4610e-05,               total_loss=5.9236e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 4.0915e-05, val_ODE: 6.3912e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 31:
# IC=4.2297e-05,               ODE=5.1559e-04,               data=7.9142e-05,               total_loss=5.5788e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 3.2307e-05, val_ODE: 5.7848e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 32:
# IC=3.2959e-05,               ODE=5.1447e-04,               data=7.1751e-05,               total_loss=5.4743e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 3.7130e-05, val_ODE: 5.2621e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 33:
# IC=4.2997e-05,               ODE=5.6475e-04,               data=8.3273e-05,               total_loss=6.0774e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 5.1539e-05, val_ODE: 5.0956e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 34:
# IC=4.8504e-05,               ODE=5.1813e-04,               data=8.5704e-05,               total_loss=5.6664e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 3.4313e-05, val_ODE: 4.6650e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 35:
# IC=3.8951e-05,               ODE=5.3126e-04,               data=7.8540e-05,               total_loss=5.7021e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 5.0335e-05, val_ODE: 5.2658e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 36:
# IC=3.4450e-05,               ODE=4.9821e-04,               data=6.7261e-05,               total_loss=5.3266e-04
# 1/1 [==============================] - 0s 30ms/step
# val_IC: 3.0078e-05, val_ODE: 4.8995e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 37:
# IC=2.8850e-05,               ODE=4.7600e-04,               data=6.1697e-05,               total_loss=5.0485e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 3.1780e-05, val_ODE: 7.0645e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 38:
# IC=3.8726e-05,               ODE=5.5684e-04,               data=8.5105e-05,               total_loss=5.9556e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 4.9788e-05, val_ODE: 4.1753e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 39:
# IC=3.5582e-05,               ODE=4.0993e-04,               data=6.2954e-05,               total_loss=4.4552e-04
# 1/1 [==============================] - 0s 28ms/step
# val_IC: 2.7460e-05, val_ODE: 4.2018e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 40:
# IC=3.5151e-05,               ODE=5.2768e-04,               data=8.0017e-05,               total_loss=5.6283e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.8847e-05, val_ODE: 4.5322e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 41:
# IC=2.9512e-05,               ODE=4.1580e-04,               data=5.6611e-05,               total_loss=4.4531e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 4.6961e-05, val_ODE: 4.4176e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 42:
# IC=4.7273e-05,               ODE=5.8297e-04,               data=9.5853e-05,               total_loss=6.3024e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 4.3478e-05, val_ODE: 5.0065e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 43:
# IC=2.5488e-05,               ODE=3.9048e-04,               data=5.5468e-05,               total_loss=4.1597e-04
# 1/1 [==============================] - 0s 28ms/step
# val_IC: 2.3450e-05, val_ODE: 4.6197e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 44:
# IC=2.9834e-05,               ODE=4.3254e-04,               data=6.2939e-05,               total_loss=4.6238e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 6.7838e-05, val_ODE: 5.0385e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 45:
# IC=3.2424e-05,               ODE=4.5400e-04,               data=6.6111e-05,               total_loss=4.8642e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 2.4240e-05, val_ODE: 3.8143e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 46:
# IC=2.5206e-05,               ODE=3.9764e-04,               data=5.4779e-05,               total_loss=4.2284e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.1901e-05, val_ODE: 3.6347e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 47:
# IC=2.9218e-05,               ODE=4.7793e-04,               data=7.4847e-05,               total_loss=5.0715e-04
# 1/1 [==============================] - 0s 27ms/step
# val_IC: 2.2869e-05, val_ODE: 4.0710e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 48:
# IC=3.7186e-05,               ODE=4.9539e-04,               data=7.4439e-05,               total_loss=5.3257e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.8173e-05, val_ODE: 3.5771e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 49:
# IC=2.4579e-05,               ODE=3.7960e-04,               data=5.1416e-05,               total_loss=4.0418e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 4.7119e-05, val_ODE: 5.7915e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 50:
# IC=2.2984e-05,               ODE=3.6528e-04,               data=5.1134e-05,               total_loss=3.8826e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.2307e-05, val_ODE: 3.6167e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 51:
# IC=4.5952e-05,               ODE=5.1560e-04,               data=9.2600e-05,               total_loss=5.6155e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 3.6546e-05, val_ODE: 3.3476e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 52:
# IC=4.3505e-05,               ODE=4.8105e-04,               data=8.4994e-05,               total_loss=5.2456e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 3.1131e-05, val_ODE: 3.4724e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 53:
# IC=2.6152e-05,               ODE=3.6757e-04,               data=5.3752e-05,               total_loss=3.9372e-04
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 1.9522e-05, val_ODE: 3.2710e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 54:
# IC=2.8153e-05,               ODE=4.0211e-04,               data=6.1984e-05,               total_loss=4.3027e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 2.8423e-05, val_ODE: 3.7680e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 55:
# IC=2.0467e-05,               ODE=3.5709e-04,               data=4.8655e-05,               total_loss=3.7756e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 2.5096e-05, val_ODE: 3.5369e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 56:
# IC=3.1964e-05,               ODE=3.6627e-04,               data=6.0556e-05,               total_loss=3.9823e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 2.2947e-05, val_ODE: 3.2496e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 57:
# IC=2.7212e-05,               ODE=4.0921e-04,               data=6.8387e-05,               total_loss=4.3643e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 5.4663e-05, val_ODE: 6.7573e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 58:
# IC=2.2081e-05,               ODE=3.1762e-04,               data=4.8717e-05,               total_loss=3.3970e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.9639e-05, val_ODE: 2.9786e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 59:
# IC=3.8636e-05,               ODE=4.6281e-04,               data=7.7213e-05,               total_loss=5.0145e-04
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 3.8344e-05, val_ODE: 3.9966e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 60:
# IC=1.9180e-05,               ODE=2.8878e-04,               data=4.1548e-05,               total_loss=3.0796e-04
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 9.6758e-06, val_ODE: 2.4783e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 61:
# IC=3.3226e-05,               ODE=4.1945e-04,               data=6.9613e-05,               total_loss=4.5268e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 9.5530e-06, val_ODE: 2.9011e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 62:
# IC=2.5191e-05,               ODE=3.0971e-04,               data=5.2152e-05,               total_loss=3.3490e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 2.2363e-05, val_ODE: 4.2772e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 63:
# IC=4.2785e-05,               ODE=3.5289e-04,               data=7.2687e-05,               total_loss=3.9568e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.6364e-05, val_ODE: 4.8864e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 64:
# IC=2.4967e-05,               ODE=2.7212e-04,               data=5.2846e-05,               total_loss=2.9708e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.1332e-05, val_ODE: 3.5318e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 65:
# IC=3.9938e-05,               ODE=3.2785e-04,               data=6.4728e-05,               total_loss=3.6779e-04
# 1/1 [==============================] - 0s 41ms/step
# val_IC: 3.4013e-05, val_ODE: 9.1554e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 66:
# IC=1.0590e-04,               ODE=4.7686e-04,               data=1.6867e-04,               total_loss=5.8276e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 2.9788e-05, val_ODE: 2.9560e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 67:
# IC=3.5823e-05,               ODE=2.8341e-04,               data=6.1209e-05,               total_loss=3.1924e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.2148e-05, val_ODE: 2.5598e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 68:
# IC=2.1888e-05,               ODE=2.3787e-04,               data=4.8142e-05,               total_loss=2.5976e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.8232e-05, val_ODE: 3.8392e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 69:
# IC=3.1518e-05,               ODE=2.9227e-04,               data=6.1711e-05,               total_loss=3.2379e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 4.6693e-05, val_ODE: 2.7086e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 70:
# IC=3.0128e-05,               ODE=3.1486e-04,               data=5.8423e-05,               total_loss=3.4499e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.6839e-05, val_ODE: 1.6543e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 71:
# IC=2.5616e-05,               ODE=2.2583e-04,               data=4.6309e-05,               total_loss=2.5144e-04
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 4.5758e-05, val_ODE: 4.4704e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 72:
# IC=2.8277e-05,               ODE=2.8524e-04,               data=5.8787e-05,               total_loss=3.1352e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 9.6700e-06, val_ODE: 2.2286e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 73:
# IC=2.2195e-05,               ODE=2.5551e-04,               data=5.1349e-05,               total_loss=2.7771e-04
# 1/1 [==============================] - 0s 34ms/step
# val_IC: 1.4805e-05, val_ODE: 2.1808e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 74:
# IC=2.0980e-05,               ODE=2.2247e-04,               data=4.4094e-05,               total_loss=2.4345e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 1.3760e-05, val_ODE: 3.4179e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 75:
# IC=4.9232e-05,               ODE=3.5337e-04,               data=8.3584e-05,               total_loss=4.0260e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 6.3915e-05, val_ODE: 3.1449e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 76:
# IC=4.5966e-05,               ODE=2.8446e-04,               data=7.4517e-05,               total_loss=3.3042e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 3.8595e-05, val_ODE: 2.7636e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 77:
# IC=1.9813e-05,               ODE=1.6214e-04,               data=3.8709e-05,               total_loss=1.8196e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 8.1024e-05, val_ODE: 9.6544e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 78:
# IC=4.2409e-05,               ODE=3.2665e-04,               data=7.7983e-05,               total_loss=3.6906e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 4.1850e-05, val_ODE: 2.4813e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 79:
# IC=1.8791e-05,               ODE=2.0529e-04,               data=4.6265e-05,               total_loss=2.2408e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 8.6809e-06, val_ODE: 2.7257e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 80:
# IC=1.5708e-05,               ODE=2.0658e-04,               data=3.8202e-05,               total_loss=2.2229e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 2.1377e-05, val_ODE: 1.8292e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 81:
# IC=2.5502e-05,               ODE=2.3004e-04,               data=4.9790e-05,               total_loss=2.5554e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 3.5502e-05, val_ODE: 3.2435e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 82:
# IC=2.8038e-05,               ODE=2.8472e-04,               data=5.6448e-05,               total_loss=3.1275e-04
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 2.4080e-05, val_ODE: 2.1386e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 83:
# IC=6.6392e-05,               ODE=4.2204e-04,               data=1.0554e-04,               total_loss=4.8843e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 5.4893e-06, val_ODE: 2.2608e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 84:
# IC=2.0681e-05,               ODE=1.6542e-04,               data=3.7885e-05,               total_loss=1.8610e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 7.9009e-06, val_ODE: 1.2738e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 85:
# IC=2.1456e-05,               ODE=1.8982e-04,               data=4.3797e-05,               total_loss=2.1128e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 8.1486e-06, val_ODE: 1.5835e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 86:
# IC=3.0423e-05,               ODE=2.5797e-04,               data=5.4416e-05,               total_loss=2.8839e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 2.4592e-05, val_ODE: 2.1535e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 87:
# IC=1.5738e-05,               ODE=1.8503e-04,               data=3.8352e-05,               total_loss=2.0077e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 2.0677e-05, val_ODE: 4.8911e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 88:
# IC=1.8959e-05,               ODE=3.1025e-04,               data=5.7127e-05,               total_loss=3.2921e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.8274e-05, val_ODE: 3.4216e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 89:
# IC=2.0802e-05,               ODE=1.5844e-04,               data=3.6164e-05,               total_loss=1.7924e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 2.0890e-05, val_ODE: 1.9677e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 90:
# IC=2.4389e-05,               ODE=2.0604e-04,               data=4.6993e-05,               total_loss=2.3043e-04
# 1/1 [==============================] - 0s 27ms/step
# val_IC: 1.6182e-05, val_ODE: 2.5300e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 91:
# IC=1.7165e-05,               ODE=2.3529e-04,               data=4.6348e-05,               total_loss=2.5246e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 5.8984e-05, val_ODE: 1.2995e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 92:
# IC=2.8029e-05,               ODE=2.3528e-04,               data=5.4367e-05,               total_loss=2.6331e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 4.0199e-05, val_ODE: 2.4004e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 93:
# IC=1.8230e-05,               ODE=1.9096e-04,               data=4.0192e-05,               total_loss=2.0919e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 8.2454e-06, val_ODE: 1.5706e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 94:
# IC=1.3664e-05,               ODE=1.6579e-04,               data=3.2387e-05,               total_loss=1.7945e-04
# 1/1 [==============================] - 0s 35ms/step
# val_IC: 1.7151e-05, val_ODE: 9.2524e-05, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 95:
# IC=5.3182e-05,               ODE=3.9304e-04,               data=8.9017e-05,               total_loss=4.4622e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 5.4145e-05, val_ODE: 3.3074e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 96:
# IC=2.0134e-05,               ODE=1.6483e-04,               data=3.6549e-05,               total_loss=1.8496e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 9.2498e-06, val_ODE: 1.0470e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 97:
# IC=1.2614e-05,               ODE=1.8113e-04,               data=3.6864e-05,               total_loss=1.9374e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 6.8523e-06, val_ODE: 1.5629e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 98:
# IC=1.6904e-05,               ODE=1.8134e-04,               data=3.9636e-05,               total_loss=1.9824e-04
# 1/1 [==============================] - 0s 28ms/step
# val_IC: 8.1450e-06, val_ODE: 9.1665e-05, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 99:
# IC=2.0230e-05,               ODE=1.7774e-04,               data=4.0329e-05,               total_loss=1.9797e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 2.2231e-05, val_ODE: 1.2295e-04, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 100:
# IC=4.6972e-02,               ODE=1.4759e-01,               data=1.6947e-02,               total_loss=1.9456e-01
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 4.7880e-02, val_ODE: 1.0823e-01, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 101:
# IC=8.4928e-03,               ODE=3.5434e-02,               data=7.5066e-03,               total_loss=4.3927e-02
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 7.9542e-04, val_ODE: 8.5067e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 102:
# IC=6.2912e-04,               ODE=6.3566e-03,               data=1.1638e-03,               total_loss=6.9857e-03
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 4.3123e-04, val_ODE: 5.0757e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 103:
# IC=3.3098e-04,               ODE=4.4408e-03,               data=6.2521e-04,               total_loss=4.7717e-03
# 1/1 [==============================] - 0s 27ms/step
# val_IC: 2.6015e-04, val_ODE: 3.9226e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 104:
# IC=2.2681e-04,               ODE=3.6110e-03,               data=4.2647e-04,               total_loss=3.8378e-03
# 1/1 [==============================] - 0s 34ms/step
# val_IC: 2.5139e-04, val_ODE: 3.3111e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 105:
# IC=1.8252e-04,               ODE=3.1250e-03,               data=3.3477e-04,               total_loss=3.3075e-03
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 1.5568e-04, val_ODE: 2.8699e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 106:
# IC=1.4985e-04,               ODE=2.7717e-03,               data=2.7096e-04,               total_loss=2.9216e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 2.1848e-04, val_ODE: 2.7007e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 107:
# IC=1.3322e-04,               ODE=2.5081e-03,               data=2.2745e-04,               total_loss=2.6413e-03
# 1/1 [==============================] - 0s 31ms/step
# val_IC: 1.7261e-04, val_ODE: 2.3202e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 108:
# IC=1.1972e-04,               ODE=2.3057e-03,               data=1.9275e-04,               total_loss=2.4254e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.3286e-04, val_ODE: 2.2317e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 109:
# IC=1.0315e-04,               ODE=2.1311e-03,               data=1.7055e-04,               total_loss=2.2343e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.4857e-04, val_ODE: 2.0524e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 110:
# IC=9.6164e-05,               ODE=1.9731e-03,               data=1.4758e-04,               total_loss=2.0693e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.3061e-04, val_ODE: 1.8604e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 111:
# IC=9.0681e-05,               ODE=1.8267e-03,               data=1.3535e-04,               total_loss=1.9174e-03
# 1/1 [==============================] - 0s 35ms/step
# val_IC: 1.1257e-04, val_ODE: 1.7337e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 112:
# IC=8.6340e-05,               ODE=1.6820e-03,               data=1.2650e-04,               total_loss=1.7684e-03
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.0213e-04, val_ODE: 1.6214e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 113:
# IC=7.5627e-05,               ODE=1.5263e-03,               data=1.1357e-04,               total_loss=1.6019e-03
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 1.1860e-04, val_ODE: 1.4013e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 114:
# IC=8.0303e-05,               ODE=1.3592e-03,               data=1.1266e-04,               total_loss=1.4395e-03
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.1823e-04, val_ODE: 1.3360e-03, lr: 1.00e-03
#
# a: [0.5], b: [0.5]
# Epoch 115:
# IC=6.3734e-05,               ODE=1.2228e-03,               data=9.4245e-05,               total_loss=1.2865e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 9.8734e-05, val_ODE: 1.2045e-03, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 116:
# IC=6.5186e-05,               ODE=1.1434e-03,               data=9.5181e-05,               total_loss=1.2086e-03
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.0262e-04, val_ODE: 1.0783e-03, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 117:
# IC=6.3512e-05,               ODE=1.0562e-03,               data=9.0479e-05,               total_loss=1.1197e-03
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.2961e-04, val_ODE: 9.9560e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 118:
# IC=6.0311e-05,               ODE=9.7692e-04,               data=8.7524e-05,               total_loss=1.0372e-03
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.0088e-04, val_ODE: 9.7268e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 119:
# IC=5.6747e-05,               ODE=9.0458e-04,               data=8.2131e-05,               total_loss=9.6133e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 8.9373e-05, val_ODE: 8.9684e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 120:
# IC=5.5791e-05,               ODE=8.4206e-04,               data=7.9701e-05,               total_loss=8.9785e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 7.7956e-05, val_ODE: 8.3061e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 121:
# IC=5.1255e-05,               ODE=7.8621e-04,               data=7.5615e-05,               total_loss=8.3746e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 7.7613e-05, val_ODE: 7.6697e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 122:
# IC=5.0569e-05,               ODE=7.4445e-04,               data=7.2979e-05,               total_loss=7.9501e-04
# 1/1 [==============================] - 0s 30ms/step
# val_IC: 7.3678e-05, val_ODE: 7.1922e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 123:
# IC=4.7009e-05,               ODE=7.0002e-04,               data=6.8322e-05,               total_loss=7.4703e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 8.7160e-05, val_ODE: 6.9252e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 124:
# IC=4.9094e-05,               ODE=6.7243e-04,               data=7.1239e-05,               total_loss=7.2152e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 6.7051e-05, val_ODE: 6.8062e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 125:
# IC=4.6826e-05,               ODE=6.4374e-04,               data=6.7849e-05,               total_loss=6.9056e-04
# 1/1 [==============================] - 0s 28ms/step
# val_IC: 7.0370e-05, val_ODE: 6.4376e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 126:
# IC=4.2918e-05,               ODE=6.1910e-04,               data=6.4543e-05,               total_loss=6.6202e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 5.0764e-05, val_ODE: 6.1578e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 127:
# IC=4.1390e-05,               ODE=5.9384e-04,               data=6.1731e-05,               total_loss=6.3523e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 5.6459e-05, val_ODE: 6.1216e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 128:
# IC=3.9821e-05,               ODE=5.7895e-04,               data=5.8486e-05,               total_loss=6.1877e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 4.5807e-05, val_ODE: 5.7381e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 129:
# IC=3.7213e-05,               ODE=5.5579e-04,               data=5.5611e-05,               total_loss=5.9301e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 6.7602e-05, val_ODE: 5.8684e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 130:
# IC=3.4671e-05,               ODE=5.4601e-04,               data=5.2832e-05,               total_loss=5.8068e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 5.8565e-05, val_ODE: 5.9081e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 131:
# IC=3.4809e-05,               ODE=5.2328e-04,               data=5.4120e-05,               total_loss=5.5809e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 5.3097e-05, val_ODE: 5.2425e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 132:
# IC=3.7013e-05,               ODE=5.0925e-04,               data=5.5077e-05,               total_loss=5.4627e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 4.0087e-05, val_ODE: 5.0702e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 133:
# IC=3.4349e-05,               ODE=4.8926e-04,               data=5.3373e-05,               total_loss=5.2361e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 4.6334e-05, val_ODE: 4.7619e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 134:
# IC=3.3034e-05,               ODE=4.7986e-04,               data=5.1899e-05,               total_loss=5.1289e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 5.2422e-05, val_ODE: 4.7769e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 135:
# IC=3.1814e-05,               ODE=4.7125e-04,               data=4.9134e-05,               total_loss=5.0307e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 3.5837e-05, val_ODE: 4.5305e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 136:
# IC=3.3475e-05,               ODE=4.5670e-04,               data=5.0529e-05,               total_loss=4.9018e-04
# 1/1 [==============================] - 0s 29ms/step
# val_IC: 2.7588e-05, val_ODE: 4.5318e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 137:
# IC=2.7265e-05,               ODE=4.5688e-04,               data=4.6417e-05,               total_loss=4.8415e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 2.9582e-05, val_ODE: 4.4362e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 138:
# IC=2.9432e-05,               ODE=4.2767e-04,               data=4.6474e-05,               total_loss=4.5710e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 3.1974e-05, val_ODE: 4.5238e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 139:
# IC=3.2652e-05,               ODE=4.6673e-04,               data=5.3444e-05,               total_loss=4.9938e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 2.5765e-05, val_ODE: 3.9863e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 140:
# IC=3.1386e-05,               ODE=4.8051e-04,               data=5.5643e-05,               total_loss=5.1190e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 3.2570e-05, val_ODE: 4.0647e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 141:
# IC=2.5046e-05,               ODE=3.9740e-04,               data=4.0612e-05,               total_loss=4.2244e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 2.8278e-05, val_ODE: 3.6457e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 142:
# IC=3.0389e-05,               ODE=4.3883e-04,               data=5.0072e-05,               total_loss=4.6921e-04
# 1/1 [==============================] - 0s 27ms/step
# val_IC: 2.6359e-05, val_ODE: 3.7929e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 143:
# IC=3.1488e-05,               ODE=4.2512e-04,               data=5.1101e-05,               total_loss=4.5661e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 2.5616e-05, val_ODE: 3.6989e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 144:
# IC=3.2714e-05,               ODE=4.4245e-04,               data=5.2605e-05,               total_loss=4.7516e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 3.4089e-05, val_ODE: 3.6302e-04, lr: 5.00e-04
#
# a: [0.5], b: [0.5]
# Epoch 145:
# IC=1.9411e-05,               ODE=3.3380e-04,               data=3.1056e-05,               total_loss=3.5321e-04
# 1/1 [==============================] - 0s 32ms/step
# val_IC: 2.5377e-05, val_ODE: 3.3803e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 146:
# IC=1.7187e-05,               ODE=3.2862e-04,               data=2.8184e-05,               total_loss=3.4581e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 2.6301e-05, val_ODE: 3.2531e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 147:
# IC=1.6640e-05,               ODE=3.2097e-04,               data=2.7248e-05,               total_loss=3.3761e-04
# 1/1 [==============================] - 0s 27ms/step
# val_IC: 2.0907e-05, val_ODE: 3.2602e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 148:
# IC=1.6811e-05,               ODE=3.1802e-04,               data=2.7621e-05,               total_loss=3.3484e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 2.7260e-05, val_ODE: 3.2687e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 149:
# IC=1.7197e-05,               ODE=3.1773e-04,               data=2.8617e-05,               total_loss=3.3492e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 2.4238e-05, val_ODE: 3.2430e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 150:
# IC=1.7352e-05,               ODE=3.1051e-04,               data=2.7159e-05,               total_loss=3.2786e-04
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 2.0979e-05, val_ODE: 3.6351e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 151:
# IC=1.6485e-05,               ODE=3.0575e-04,               data=2.6725e-05,               total_loss=3.2224e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 2.4698e-05, val_ODE: 3.1112e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 152:
# IC=1.5525e-05,               ODE=3.0039e-04,               data=2.5709e-05,               total_loss=3.1591e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.6872e-05, val_ODE: 2.9709e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 153:
# IC=1.6516e-05,               ODE=2.9888e-04,               data=2.7469e-05,               total_loss=3.1539e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.9254e-05, val_ODE: 3.0167e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 154:
# IC=1.5387e-05,               ODE=2.9286e-04,               data=2.5902e-05,               total_loss=3.0825e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 1.7428e-05, val_ODE: 2.9583e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 155:
# IC=1.6415e-05,               ODE=2.9252e-04,               data=2.6469e-05,               total_loss=3.0893e-04
# 1/1 [==============================] - 0s 32ms/step
# val_IC: 2.0715e-05, val_ODE: 2.9391e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 156:
# IC=1.6545e-05,               ODE=2.8866e-04,               data=2.7376e-05,               total_loss=3.0520e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 2.9509e-05, val_ODE: 2.7742e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 157:
# IC=1.8918e-05,               ODE=2.8559e-04,               data=2.9301e-05,               total_loss=3.0451e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.8502e-05, val_ODE: 2.8854e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 158:
# IC=1.6324e-05,               ODE=2.8422e-04,               data=2.7011e-05,               total_loss=3.0054e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 2.4385e-05, val_ODE: 2.9658e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 159:
# IC=1.9442e-05,               ODE=2.9512e-04,               data=3.2488e-05,               total_loss=3.1456e-04
# 1/1 [==============================] - 0s 27ms/step
# val_IC: 1.5723e-05, val_ODE: 2.9262e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 160:
# IC=2.1950e-05,               ODE=3.2698e-04,               data=3.5833e-05,               total_loss=3.4894e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.5547e-05, val_ODE: 2.6618e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 161:
# IC=1.9511e-05,               ODE=2.8703e-04,               data=2.9425e-05,               total_loss=3.0654e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.7883e-05, val_ODE: 2.6740e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 162:
# IC=1.5037e-05,               ODE=2.6742e-04,               data=2.3966e-05,               total_loss=2.8245e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 3.8026e-05, val_ODE: 3.2484e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 163:
# IC=2.2886e-05,               ODE=3.1058e-04,               data=3.8024e-05,               total_loss=3.3346e-04
# 1/1 [==============================] - 0s 34ms/step
# val_IC: 1.4280e-05, val_ODE: 2.7245e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 164:
# IC=1.5088e-05,               ODE=2.7607e-04,               data=2.5006e-05,               total_loss=2.9116e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.2440e-05, val_ODE: 2.6776e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 165:
# IC=1.4498e-05,               ODE=2.5666e-04,               data=2.3268e-05,               total_loss=2.7115e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.3851e-05, val_ODE: 2.6137e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 166:
# IC=1.5999e-05,               ODE=2.5258e-04,               data=2.5055e-05,               total_loss=2.6857e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.3885e-05, val_ODE: 2.5750e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 167:
# IC=1.7509e-05,               ODE=2.7050e-04,               data=2.7268e-05,               total_loss=2.8801e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 6.2546e-05, val_ODE: 5.1427e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 168:
# IC=1.7150e-05,               ODE=2.6633e-04,               data=2.6838e-05,               total_loss=2.8348e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.6468e-05, val_ODE: 2.9390e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 169:
# IC=1.5861e-05,               ODE=2.6457e-04,               data=2.5489e-05,               total_loss=2.8043e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 1.6743e-05, val_ODE: 2.7596e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 170:
# IC=1.8087e-05,               ODE=2.5936e-04,               data=2.7487e-05,               total_loss=2.7745e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.7059e-05, val_ODE: 2.5292e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 171:
# IC=1.5950e-05,               ODE=2.5500e-04,               data=2.6273e-05,               total_loss=2.7095e-04
# 1/1 [==============================] - 0s 21ms/step
# val_IC: 1.3861e-05, val_ODE: 3.3765e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 172:
# IC=1.8176e-05,               ODE=2.6268e-04,               data=2.6574e-05,               total_loss=2.8086e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.8830e-05, val_ODE: 2.5522e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 173:
# IC=1.4720e-05,               ODE=2.3247e-04,               data=2.3816e-05,               total_loss=2.4719e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.8739e-05, val_ODE: 2.1948e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 174:
# IC=1.4986e-05,               ODE=2.2852e-04,               data=2.4391e-05,               total_loss=2.4351e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.9542e-05, val_ODE: 2.4419e-04, lr: 2.50e-04
#
# a: [0.5], b: [0.5]
# Epoch 175:
# IC=9.5042e-06,               ODE=1.9649e-04,               data=1.6039e-05,               total_loss=2.0599e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 9.7277e-06, val_ODE: 1.9607e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 176:
# IC=1.0029e-05,               ODE=1.8930e-04,               data=1.6094e-05,               total_loss=1.9932e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.0440e-05, val_ODE: 2.0660e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 177:
# IC=1.1615e-05,               ODE=1.8993e-04,               data=1.8559e-05,               total_loss=2.0154e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 1.3551e-05, val_ODE: 1.8824e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 178:
# IC=9.0734e-06,               ODE=1.8514e-04,               data=1.5024e-05,               total_loss=1.9421e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 1.1022e-05, val_ODE: 1.9808e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 179:
# IC=8.9010e-06,               ODE=1.8199e-04,               data=1.5154e-05,               total_loss=1.9089e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.2451e-05, val_ODE: 1.8817e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 180:
# IC=9.3522e-06,               ODE=1.8098e-04,               data=1.6202e-05,               total_loss=1.9033e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 8.1992e-06, val_ODE: 1.8271e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 181:
# IC=8.9925e-06,               ODE=1.7653e-04,               data=1.5040e-05,               total_loss=1.8552e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 9.6692e-06, val_ODE: 1.7931e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 182:
# IC=1.0255e-05,               ODE=1.7457e-04,               data=1.6951e-05,               total_loss=1.8482e-04
# 1/1 [==============================] - 0s 33ms/step
# val_IC: 9.4126e-06, val_ODE: 1.9954e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 183:
# IC=9.3608e-06,               ODE=1.7613e-04,               data=1.6056e-05,               total_loss=1.8549e-04
# 1/1 [==============================] - 0s 23ms/step
# val_IC: 1.3578e-05, val_ODE: 1.7668e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 184:
# IC=8.6941e-06,               ODE=1.7051e-04,               data=1.5196e-05,               total_loss=1.7920e-04
# 1/1 [==============================] - 0s 35ms/step
# val_IC: 1.1479e-05, val_ODE: 1.6570e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 185:
# IC=1.0176e-05,               ODE=1.7429e-04,               data=1.7652e-05,               total_loss=1.8447e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 1.1076e-05, val_ODE: 1.7951e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 186:
# IC=9.6121e-06,               ODE=1.6659e-04,               data=1.6261e-05,               total_loss=1.7620e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 1.0744e-05, val_ODE: 1.7346e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 187:
# IC=8.9739e-06,               ODE=1.6353e-04,               data=1.5622e-05,               total_loss=1.7251e-04
# 1/1 [==============================] - 0s 36ms/step
# val_IC: 1.2527e-05, val_ODE: 1.7298e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 188:
# IC=9.4509e-06,               ODE=1.5998e-04,               data=1.5325e-05,               total_loss=1.6943e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 7.6020e-06, val_ODE: 1.5871e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 189:
# IC=1.1700e-05,               ODE=1.6495e-04,               data=1.7610e-05,               total_loss=1.7665e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 7.4495e-06, val_ODE: 1.5452e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 190:
# IC=1.0240e-05,               ODE=1.5618e-04,               data=1.6437e-05,               total_loss=1.6642e-04
# 1/1 [==============================] - 0s 22ms/step
# val_IC: 8.3021e-06, val_ODE: 1.7507e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 191:
# IC=1.0821e-05,               ODE=1.6687e-04,               data=1.7871e-05,               total_loss=1.7769e-04
# 1/1 [==============================] - 0s 33ms/step
# val_IC: 7.7471e-06, val_ODE: 1.4443e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 192:
# IC=9.4604e-06,               ODE=1.4433e-04,               data=1.5521e-05,               total_loss=1.5379e-04
# 1/1 [==============================] - 0s 30ms/step
# val_IC: 1.2422e-05, val_ODE: 1.5037e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 193:
# IC=9.1885e-06,               ODE=1.4072e-04,               data=1.5297e-05,               total_loss=1.4991e-04
# 1/1 [==============================] - 0s 30ms/step
# val_IC: 1.5501e-05, val_ODE: 1.4560e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 194:
# IC=1.0411e-05,               ODE=1.4275e-04,               data=1.6335e-05,               total_loss=1.5316e-04
# 1/1 [==============================] - 0s 38ms/step
# val_IC: 7.7456e-06, val_ODE: 1.3234e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 195:
# IC=1.0485e-05,               ODE=1.5031e-04,               data=1.7033e-05,               total_loss=1.6079e-04
# 1/1 [==============================] - 0s 28ms/step
# val_IC: 9.3366e-06, val_ODE: 1.3659e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 196:
# IC=9.0394e-06,               ODE=1.3284e-04,               data=1.5457e-05,               total_loss=1.4188e-04
# 1/1 [==============================] - 0s 28ms/step
# val_IC: 2.7451e-05, val_ODE: 1.3192e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 197:
# IC=1.0441e-05,               ODE=1.3495e-04,               data=1.6323e-05,               total_loss=1.4540e-04
# 1/1 [==============================] - 0s 30ms/step
# val_IC: 1.5019e-05, val_ODE: 1.3910e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 198:
# IC=9.4282e-06,               ODE=1.2417e-04,               data=1.4967e-05,               total_loss=1.3360e-04
# 1/1 [==============================] - 0s 25ms/step
# val_IC: 8.2064e-06, val_ODE: 1.2378e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 199:
# IC=9.6789e-06,               ODE=1.2558e-04,               data=1.5364e-05,               total_loss=1.3526e-04
# 1/1 [==============================] - 0s 26ms/step
# val_IC: 1.3308e-05, val_ODE: 1.6933e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]
# Epoch 200:
# IC=1.5381e-05,               ODE=1.3864e-04,               data=2.2504e-05,               total_loss=1.5402e-04
# 1/1 [==============================] - 0s 24ms/step
# val_IC: 8.3277e-06, val_ODE: 1.0748e-04, lr: 1.25e-04
#
# a: [0.5], b: [0.5]

# %%
# History for loss
# %matplotlib inline
fig, ax = plt.subplots(1, 3, figsize=(15, 4))
ax[0].plot(range(n_epochs), loss_tracker.loss_history['IC_loss'])
ax[1].plot(range(n_epochs), loss_tracker.loss_history['ODE_loss'])
ax[2].plot(range(n_epochs), val_loss_hist)
ax[0].set_title('IC Loss', fontsize=14)
ax[1].set_title('ODE Loss', fontsize=14)
ax[2].set_title('Validation Loss', fontsize=14)
for axs in ax:
    axs.set_yscale('log')
    axs.tick_params(axis='both', which='major', labelsize=12)

plt.savefig('loss.png', bbox_inches='tight', pad_inches=0, transparent=True)

# %% [markdown]
# #### Inverse calibration: native TensorFlow

# %%
@tf.function
def gradient_u(model, u, s_target):
    """ Calculate the gradients of objective function with respect to u(·).

    Args:
    ----
    model: the trained PI-DeepONet model
    u: u()
    s_target: the observed s()


    Outputs:
    --------
    obj: objective function
    gradients: calculated gradients
    """

    with tf.GradientTape() as tape:
        tape.watch(u)

        # Initial condition prediction
        y_pred_IC = model({"forcing": u, "time": 0})
        IC_loss = tf.reduce_mean(keras.losses.mean_squared_error(0, y_pred_IC))

        # ODE residual
        ODE_residual = ODE_residual_calculator(t=tf.reshape(tf.linspace(0.0, 1.0, 100), (-1, 1)),
                                               u=tf.tile(tf.reshape(u, (1, -1)), [100, 1]),
                                               u_t=tf.reshape(u, (-1, 1)), model=model)
        ODE_loss = tf.reduce_mean(tf.square(ODE_residual))

        # Predict s() with the current u()
        y_pred = model({"forcing": tf.tile(tf.reshape(u, (1, -1)), [100, 1]),
                        "time": tf.reshape(tf.linspace(0.0, 1.0, 100), (-1, 1))})

        # Data loss
        data_loss = tf.reduce_mean(keras.losses.mean_squared_error(s_target, y_pred))

        # Total loss
        obj = IC_loss + ODE_loss + data_loss

    # Gradient descent
    gradients = tape.gradient(obj, u)

    return obj, gradients

# %%
def optimize_u(model, initial_u, s_target, learning_rate=5e-3, opt_steps=10000):
    """ Determine u() that generates the observed s().

    Args:
    ----
    model: the trained PI-DeepONet model
    initial_u: initial guess for u()
    s_target: the observed s()
    learning_rate: learning rate for the optimizer
    opt_steps: number of optimization iterations


    Outputs:
    --------
    u: the optimized u()
    u_hist: intermedian u results
    objective_func_hist: value history of the objective function
    """

    # Optimizer
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    # Setup u() and empty list for storing results
    u_var = tf.Variable(initial_u, dtype=tf.float32)
    objective_func_hist = []
    u_hist = []

    for step in range(opt_steps):

        # Calculate gradients
        obj, gradients = gradient_u(model, u_var, s_target)

        # Gradient descent
        optimizer.apply_gradients([(gradients, u_var)])

        # Record results
        objective_func_hist.append(obj.numpy())
        u_hist.append(u_var.numpy())

        # Show progress
        if step % 500 == 0:
            print(f'Step {step} ==> Objective function = {obj.numpy()}')

    # Optimized u()
    u = u_var.numpy()

    return u, objective_func_hist, u_hist

# %% [markdown]
# We randomly select one s() profile and see if our approach can identified the correct u() that generated the given s().

# %%
sample_id = 25
initial_u = np.zeros(100, dtype=np.float32)
s_target = y_inverse_test[sample_id*100:(sample_id+1)*100, :]
opt_u, objective_func_hist, u_hist = optimize_u(PI_DeepONet, initial_u, s_target, learning_rate=0.005, opt_steps=20000)
# Out:
# Step 0 ==> Objective function = 0.09568827599287033
# Step 500 ==> Objective function = 0.0225551575422287
# Step 1000 ==> Objective function = 0.00552108371630311
# Step 1500 ==> Objective function = 0.0007633572677150369
# Step 2000 ==> Objective function = 0.00013255585508886725
# Step 2500 ==> Objective function = 7.959264621604234e-05
# Step 3000 ==> Objective function = 6.269059667829424e-05
# Step 3500 ==> Objective function = 4.901567808701657e-05
# Step 4000 ==> Objective function = 3.7148583942325786e-05
# Step 4500 ==> Objective function = 2.9080398235237226e-05
# Step 5000 ==> Objective function = 1.8857879695133306e-05
# Step 5500 ==> Objective function = 1.3103971468808595e-05
# Step 6000 ==> Objective function = 9.304520062869415e-06
# Step 6500 ==> Objective function = 7.0849255280336365e-06
# Step 7000 ==> Objective function = 2.6852645532926545e-05
# Step 7500 ==> Objective function = 4.687217369792052e-06
# Step 8000 ==> Objective function = 4.223943506076466e-06
# Step 8500 ==> Objective function = 3.965720679843798e-06
# Step 9000 ==> Objective function = 3.925119926861953e-06
# Step 9500 ==> Objective function = 4.442811587068718e-06
# Step 10000 ==> Objective function = 4.0547101889387704e-06
# Step 10500 ==> Objective function = 6.792532076360658e-06
# Step 11000 ==> Objective function = 3.916311470675282e-06
# Step 11500 ==> Objective function = 3.789480615523644e-06
# Step 12000 ==> Objective function = 3.998494776169537e-06
# Step 12500 ==> Objective function = 3.655910859379219e-06
# Step 13000 ==> Objective function = 3.651581209851429e-06
# Step 13500 ==> Objective function = 6.920421128597809e-06
# Step 14000 ==> Objective function = 3.6495607673714403e-06
# Step 14500 ==> Objective function = 3.889223080477677e-06
# Step 15000 ==> Objective function = 3.6422147786652204e-06
# Step 15500 ==> Objective function = 3.664245014078915e-06
# Step 16000 ==> Objective function = 1.804213570721913e-05
# Step 16500 ==> Objective function = 3.6527612792269792e-06
# Step 17000 ==> Objective function = 3.6649362300522625e-06
# Step 17500 ==> Objective function = 3.640913746494334e-06
# Step 18000 ==> Objective function = 4.964163053955417e-06
# Step 18500 ==> Objective function = 5.580331162491348e-06
# Step 19000 ==> Objective function = 4.643572538043372e-06
# Step 19500 ==> Objective function = 9.616203897166997e-06

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(5, 4))
ax.plot(range(len(objective_func_hist)), objective_func_hist)
ax.set_title('Objective Function Evolution', fontsize=14)
ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=12)

plt.savefig('loss_inverse.png', bbox_inches='tight', pad_inches=0, transparent=True)

# %% [markdown]
# We can plot the convergence history

# %%
# %matplotlib inline
indices = [0, 3999, 7999, 11999, 15999, 19999]
fig, axs = plt.subplots(2, 3, figsize=(13, 6))
for i in range(6):
    ax = axs[i//3, i%3]
    ax.plot(np.linspace(0, 1, 100), X_inverse_test[sample_id*100, 1:-1], lw=4, c='r', label='Ground truth')
    ax.plot(np.linspace(0, 1, 100), u_hist[indices[i]], lw=4, label='Calibration')
    ax.set_xlabel('t', fontsize=14)
    ax.set_ylabel('u(t)', fontsize=14)
    ax.set_title(f'Iteration {indices[i]+1}', fontsize=14)
    ax.tick_params(axis='both', which='major', labelsize=12)
    ax.legend()
    ax.grid(True)
plt.tight_layout()
plt.savefig('u_history.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# Forward simulation: predicting s() given the calibrated u()

# %%
# %matplotlib inline
fig, ax = plt.subplots(1, 2, figsize=(8, 3))
ax[0].plot(np.linspace(0, 1, 100), opt_u, label='Calibration', lw=4)
ax[0].plot(np.linspace(0, 1, 100), X_inverse_test[sample_id*100, 1:-1], label='Ground truth', lw=4)
ax[0].set_title('u(t)', fontsize=14)


# Inference pipeline
dataset = np.concatenate([np.linspace(0, 1, 100).reshape(-1, 1), np.tile(opt_u, (100, 1))], axis=1)
pred = PI_DeepONet.predict({"forcing": dataset[:, 1:], "time": dataset[:, :1]}, batch_size=12800)
ax[1].plot(np.linspace(0, 1, 100), pred.flatten(), label='Calibration', lw=4)

# ODE solver
t = np.linspace(0, 1, 100)
sol = solve_ivp(lambda var_t, var_s: a*np.interp(var_t, t, opt_u)+b,
                t_span=[0, 1], y0=[0], t_eval=t, method='RK45')
ax[1].plot(np.linspace(0, 1, 100), sol.y[0], label='ODE Solver', lw=4)

# Ground truth
ax[1].plot(np.linspace(0, 1, 100), y_target.flatten(), label='Ground truth', lw=4)

ax[1].set_title('s(t)', fontsize=14)

for axs in ax:
    axs.legend()
    axs.grid(True)
    axs.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.savefig('s_prediction.png', bbox_inches='tight', transparent=True)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f042624525a0> in <cell line: 0>()
#      18
#      19 # Ground truth
# ---> 20 ax[1].plot(np.linspace(0, 1, 100), y_target.flatten(), label='Ground truth', lw=4)
#      21
#      22 ax[1].set_title('s(t)', fontsize=14)
#
# NameError: name 'y_target' is not defined

# %% [markdown]
# We further test other u() profiles to see if the approach works properly

# %%
opt_u_list = []
sample_id_list = []
for i in range(6):
    sample_id = np.random.randint(0, 100)
    print(f"Start {i+1} iteration, picked {sample_id}-th sample!")
    initial_u = np.zeros(100, dtype=np.float32)
    s_target = y_inverse_test[sample_id*100:(sample_id+1)*100, :]
    opt_u, _, _ = optimize_u(PI_DeepONet, initial_u, s_target, learning_rate=0.005, opt_steps=20000)
    opt_u_list.append(opt_u)
    sample_id_list.append(sample_id)
# Out:
# Start 1 iteration, picked 7-th sample!
# Step 0 ==> Objective function = 0.004761198069900274
# Step 500 ==> Objective function = 0.0007003493956290185
# Step 1000 ==> Objective function = 0.0002120095887221396
# Step 1500 ==> Objective function = 6.408189074136317e-05
# Step 2000 ==> Objective function = 7.07293875166215e-05
# Step 2500 ==> Objective function = 1.5393605281133205e-05
# Step 3000 ==> Objective function = 1.1964139048359357e-05
# Step 3500 ==> Objective function = 9.451536243432201e-06
# Step 4000 ==> Objective function = 8.314028491440695e-06
# Step 4500 ==> Objective function = 7.510782324970933e-06
# Step 5000 ==> Objective function = 4.593039193423465e-05
# Step 5500 ==> Objective function = 1.0804169505718164e-05
# Step 6000 ==> Objective function = 6.246767043194268e-06
# Step 6500 ==> Objective function = 4.752434506372083e-06
# Step 7000 ==> Objective function = 1.1126161552965641e-05
# Step 7500 ==> Objective function = 4.000751687271986e-06
# Step 8000 ==> Objective function = 4.001982233603485e-06
# Step 8500 ==> Objective function = 3.908774033334339e-06
# Step 9000 ==> Objective function = 3.43892429555126e-06
# Step 9500 ==> Objective function = 2.9621510293509346e-06
# Step 10000 ==> Objective function = 2.9736338547081687e-06
# Step 10500 ==> Objective function = 2.9450402507791296e-06
# Step 11000 ==> Objective function = 2.4374908207391854e-06
# Step 11500 ==> Objective function = 2.631409006426111e-05
# Step 12000 ==> Objective function = 2.306946498720208e-06
# Step 12500 ==> Objective function = 2.110105469910195e-06
# Step 13000 ==> Objective function = 2.1376820313889766e-06
# Step 13500 ==> Objective function = 6.3654943005531095e-06
# Step 14000 ==> Objective function = 2.130777374986792e-06
# Step 14500 ==> Objective function = 1.0866092452488374e-05
# Step 15000 ==> Objective function = 8.724589133635163e-05
# Step 15500 ==> Objective function = 1.2529530067695305e-05
# Step 16000 ==> Objective function = 1.487676740907773e-06
# Step 16500 ==> Objective function = 1.6431065432698233e-06
# Step 17000 ==> Objective function = 1.3835874597134534e-06
# Step 17500 ==> Objective function = 1.339109985565301e-06
# Step 18000 ==> Objective function = 4.3579539124039e-06
# Step 18500 ==> Objective function = 4.2196488720946945e-06
# Step 19000 ==> Objective function = 1.2289247024455108e-06
# Step 19500 ==> Objective function = 1.1960779602304683e-06
# Start 2 iteration, picked 26-th sample!
# Step 0 ==> Objective function = 0.20678330957889557
# Step 500 ==> Objective function = 0.06125172972679138
# Step 1000 ==> Objective function = 0.02680649235844612
# Step 1500 ==> Objective function = 0.00923159159719944
# Step 2000 ==> Objective function = 0.0033370242454111576
# Step 2500 ==> Objective function = 0.001598441507667303
# Step 3000 ==> Objective function = 0.0008352459408342838
# Step 3500 ==> Objective function = 0.00040523262578062713
# Step 4000 ==> Objective function = 0.00018551028915680945
# Step 4500 ==> Objective function = 8.675090793985873e-05
# Step 5000 ==> Objective function = 4.275761602912098e-05
# Step 5500 ==> Objective function = 2.11469414352905e-05
# Step 6000 ==> Objective function = 1.3876717275707051e-05
# Step 6500 ==> Objective function = 6.275717169046402e-06
# Step 7000 ==> Objective function = 3.92072206523153e-06
# Step 7500 ==> Objective function = 3.077971086895559e-06
# Step 8000 ==> Objective function = 2.686035941223963e-06
# Step 8500 ==> Objective function = 1.5438003174494952e-05
# Step 9000 ==> Objective function = 3.299502395748277e-06
# Step 9500 ==> Objective function = 2.400746552666533e-06
# Step 10000 ==> Objective function = 4.1674757085274905e-06
# Step 10500 ==> Objective function = 2.273021436849376e-06
# Step 11000 ==> Objective function = 4.2258811845385935e-06
# Step 11500 ==> Objective function = 1.413439167663455e-05
# Step 12000 ==> Objective function = 2.290982138219988e-06
# Step 12500 ==> Objective function = 2.3059469640429597e-06
# Step 13000 ==> Objective function = 2.2477327092929045e-06
# Step 13500 ==> Objective function = 2.272241545142606e-06
# Step 14000 ==> Objective function = 2.3302332010644022e-06
# Step 14500 ==> Objective function = 2.2469391751656076e-06
# Step 15000 ==> Objective function = 2.272441633976996e-06
# Step 15500 ==> Objective function = 5.685364158125594e-06
# Step 16000 ==> Objective function = 2.247946440547821e-06
# Step 16500 ==> Objective function = 3.3527148843859322e-06
# Step 17000 ==> Objective function = 2.400964604021283e-06
# Step 17500 ==> Objective function = 3.225875843781978e-06
# Step 18000 ==> Objective function = 2.26921952162229e-06
# Step 18500 ==> Objective function = 9.524010238237679e-06
# Step 19000 ==> Objective function = 5.2911595957993995e-06
# Step 19500 ==> Objective function = 1.321646232099738e-05
# Start 3 iteration, picked 31-th sample!
# Step 0 ==> Objective function = 0.0021232631988823414
# Step 500 ==> Objective function = 0.00025724584702402353
# Step 1000 ==> Objective function = 7.960460789036006e-05
# Step 1500 ==> Objective function = 4.278092092135921e-05
# Step 2000 ==> Objective function = 1.9789909856626764e-05
# Step 2500 ==> Objective function = 1.8710275980993174e-05
# Step 3000 ==> Objective function = 1.011666790873278e-05
# Step 3500 ==> Objective function = 5.3545718401437625e-06
# Step 4000 ==> Objective function = 4.203294793114765e-06
# Step 4500 ==> Objective function = 3.317123400847777e-06
# Step 5000 ==> Objective function = 2.771339950413676e-06
# Step 5500 ==> Objective function = 2.405121449555736e-06
# Step 6000 ==> Objective function = 2.1337632460927125e-06
# Step 6500 ==> Objective function = 2.0623504042305285e-06
# Step 7000 ==> Objective function = 1.7650453401074628e-06
# Step 7500 ==> Objective function = 2.3784511995472712e-06
# Step 8000 ==> Objective function = 1.9730146050278563e-06
# Step 8500 ==> Objective function = 1.4524075595545582e-06
# Step 9000 ==> Objective function = 3.89379511034349e-06
# Step 9500 ==> Objective function = 1.3815622423862806e-06
# Step 10000 ==> Objective function = 1.2714313015749212e-06
# Step 10500 ==> Objective function = 1.229871259056381e-06
# Step 11000 ==> Objective function = 1.1940426247747382e-06
# Step 11500 ==> Objective function = 1.1812667253252584e-06
# Step 12000 ==> Objective function = 1.148270939665963e-06
# Step 12500 ==> Objective function = 1.129926431531203e-06
# Step 13000 ==> Objective function = 3.6352080314827617e-06
# Step 13500 ==> Objective function = 1.0907194791798247e-06
# Step 14000 ==> Objective function = 1.2584298474394018e-06
# Step 14500 ==> Objective function = 1.0953990567941219e-06
# Step 15000 ==> Objective function = 9.259180842491332e-06
# Step 15500 ==> Objective function = 1.966285026355763e-06
# Step 16000 ==> Objective function = 1.1228429457332822e-06
# Step 16500 ==> Objective function = 1.0355848871768103e-06
# Step 17000 ==> Objective function = 3.02295848086942e-05
# Step 17500 ==> Objective function = 5.862968009751057e-06
# Step 18000 ==> Objective function = 1.5800230812601512e-06
# Step 18500 ==> Objective function = 2.1197356545599177e-06
# Step 19000 ==> Objective function = 1.057731537912332e-06
# Step 19500 ==> Objective function = 1.0902233498200076e-06
# Start 4 iteration, picked 17-th sample!
# Step 0 ==> Objective function = 0.02409314177930355
# Step 500 ==> Objective function = 0.003963327035307884
# Step 1000 ==> Objective function = 0.0008997246623039246
# Step 1500 ==> Objective function = 0.0004220645932946354
# Step 2000 ==> Objective function = 0.00021112256217747927
# Step 2500 ==> Objective function = 0.00010122250387212262
# Step 3000 ==> Objective function = 4.5559179852716625e-05
# Step 3500 ==> Objective function = 1.9521945432643406e-05
# Step 4000 ==> Objective function = 8.755853741604369e-06
# Step 4500 ==> Objective function = 4.528630142885959e-06
# Step 5000 ==> Objective function = 2.7854011932504363e-06
# Step 5500 ==> Objective function = 1.9535073079168797e-06
# Step 6000 ==> Objective function = 4.177150913164951e-06
# Step 6500 ==> Objective function = 1.4545697695211857e-06
# Step 7000 ==> Objective function = 1.1646883422145038e-06
# Step 7500 ==> Objective function = 9.872306918623508e-07
# Step 8000 ==> Objective function = 9.271241765418381e-07
# Step 8500 ==> Objective function = 1.0249829074382433e-06
# Step 9000 ==> Objective function = 8.667753377267218e-07
# Step 9500 ==> Objective function = 8.532352353540773e-07
# Step 10000 ==> Objective function = 8.480558335577371e-07
# Step 10500 ==> Objective function = 9.448768309994193e-07
# Step 11000 ==> Objective function = 8.508775977134064e-07
# Step 11500 ==> Objective function = 2.611596300994279e-06
# Step 12000 ==> Objective function = 8.626637963971007e-07
# Step 12500 ==> Objective function = 1.4346794614539249e-06
# Step 13000 ==> Objective function = 8.590188826929079e-07
# Step 13500 ==> Objective function = 3.950914560846286e-06
# Step 14000 ==> Objective function = 8.315223567478824e-07
# Step 14500 ==> Objective function = 1.030778776112129e-06
# Step 15000 ==> Objective function = 2.822861006279709e-06
# Step 15500 ==> Objective function = 8.906897051019769e-07
# Step 16000 ==> Objective function = 3.7635186345141847e-06
# Step 16500 ==> Objective function = 8.657179932924919e-07
# Step 17000 ==> Objective function = 1.9765926481341012e-05
# Step 17500 ==> Objective function = 4.297828127164394e-06
# Step 18000 ==> Objective function = 8.387312391278101e-07
# Step 18500 ==> Objective function = 8.809935252429568e-07
# Step 19000 ==> Objective function = 3.6040551094629336e-06
# Step 19500 ==> Objective function = 9.507731988378509e-07
# Start 5 iteration, picked 12-th sample!
# Step 0 ==> Objective function = 0.05842582508921623
# Step 500 ==> Objective function = 0.01645461656153202
# Step 1000 ==> Objective function = 0.005569892469793558
# Step 1500 ==> Objective function = 0.002391187706962228
# Step 2000 ==> Objective function = 0.0009932990651577711
# Step 2500 ==> Objective function = 0.00034577626502141356
# Step 3000 ==> Objective function = 0.00011640027514658868
# Step 3500 ==> Objective function = 5.0618924433365464e-05
# Step 4000 ==> Objective function = 2.7972422685706988e-05
# Step 4500 ==> Objective function = 1.616932058823295e-05
# Step 5000 ==> Objective function = 1.0005514013755601e-05
# Step 5500 ==> Objective function = 5.406712716649054e-06
# Step 6000 ==> Objective function = 4.677371180150658e-06
# Step 6500 ==> Objective function = 2.7728206077881623e-06
# Step 7000 ==> Objective function = 1.4093260460867896e-06
# Step 7500 ==> Objective function = 9.752112646310707e-07
# Step 8000 ==> Objective function = 1.4413693634196534e-06
# Step 8500 ==> Objective function = 6.638636591560498e-07
# Step 9000 ==> Objective function = 6.029169981047744e-07
# Step 9500 ==> Objective function = 5.66867299767182e-07
# Step 10000 ==> Objective function = 5.473073088069214e-07
# Step 10500 ==> Objective function = 1.4335483911054325e-06
# Step 11000 ==> Objective function = 6.381278581102379e-07
# Step 11500 ==> Objective function = 1.0157134511246113e-06
# Step 12000 ==> Objective function = 5.257043653728033e-07
# Step 12500 ==> Objective function = 1.1429403912188718e-06
# Step 13000 ==> Objective function = 5.232319608694525e-07
# Step 13500 ==> Objective function = 5.917957878409652e-06
# Step 14000 ==> Objective function = 6.029095516169036e-07
# Step 14500 ==> Objective function = 5.262061790745065e-07
# Step 15000 ==> Objective function = 4.136903953622095e-06
# Step 15500 ==> Objective function = 5.241412850409688e-07
# Step 16000 ==> Objective function = 1.844690996222198e-05
# Step 16500 ==> Objective function = 6.068274842618848e-07
# Step 17000 ==> Objective function = 5.237355935605592e-07
# Step 17500 ==> Objective function = 6.580299896086217e-07
# Step 18000 ==> Objective function = 1.626331686566118e-05
# Step 18500 ==> Objective function = 5.685126893695269e-07
# Step 19000 ==> Objective function = 5.434297918327502e-07
# Step 19500 ==> Objective function = 1.1909448403457645e-05
# Start 6 iteration, picked 71-th sample!
# Step 0 ==> Objective function = 0.07754001766443253
# Step 500 ==> Objective function = 0.017575260251760483
# Step 1000 ==> Objective function = 0.006160349119454622
# Step 1500 ==> Objective function = 0.0024203697685152292
# Step 2000 ==> Objective function = 0.0011423901887610555
# Step 2500 ==> Objective function = 0.0004961249651387334
# Step 3000 ==> Objective function = 0.0001854079164331779
# Step 3500 ==> Objective function = 6.469448999268934e-05
# Step 4000 ==> Objective function = 2.374791438342072e-05
# Step 4500 ==> Objective function = 1.41798682307126e-05
# Step 5000 ==> Objective function = 1.565801903780084e-05
# Step 5500 ==> Objective function = 1.560139480716316e-06
# Step 6000 ==> Objective function = 1.0495007245481247e-06
# Step 6500 ==> Objective function = 1.0127241694135591e-06
# Step 7000 ==> Objective function = 8.985273325379239e-07
# Step 7500 ==> Objective function = 1.0727966582635418e-05
# Step 8000 ==> Objective function = 3.8035711895645363e-06
# Step 8500 ==> Objective function = 8.887545845936984e-07
# Step 9000 ==> Objective function = 8.876277206582017e-07
# Step 9500 ==> Objective function = 2.1924370230408385e-06
# Step 10000 ==> Objective function = 6.215665052877739e-06
# Step 10500 ==> Objective function = 1.2865461940236855e-06
# Step 11000 ==> Objective function = 1.5730981886008522e-06
# Step 11500 ==> Objective function = 4.3568229557422455e-06
# Step 12000 ==> Objective function = 2.020623469434213e-06
# Step 12500 ==> Objective function = 8.982559620562824e-07
# Step 13000 ==> Objective function = 8.81045707501471e-07
# Step 13500 ==> Objective function = 1.3889455203752732e-06
# Step 14000 ==> Objective function = 9.211109500029124e-06
# Step 14500 ==> Objective function = 2.3817169676476624e-06
# Step 15000 ==> Objective function = 2.478315309417667e-06
# Step 15500 ==> Objective function = 8.789725143287797e-07
# Step 16000 ==> Objective function = 1.6290173334709834e-06
# Step 16500 ==> Objective function = 9.105922345042927e-07
# Step 17000 ==> Objective function = 9.293224820794421e-07
# Step 17500 ==> Objective function = 3.2921550428000046e-06
# Step 18000 ==> Objective function = 9.408037158209481e-07
# Step 18500 ==> Objective function = 8.791378149908269e-07
# Step 19000 ==> Objective function = 2.7233704713580664e-06
# Step 19500 ==> Objective function = 8.831999593894579e-07

# %%
# %matplotlib inline
fig, axs = plt.subplots(2, 3, figsize=(13, 6))
sample_id_list = [13, 85, 73, 28, 51, 16]
for i in range(6):
    ax = axs[i//3, i%3]

    ax.plot(np.linspace(0, 1, 100), opt_u_list[i], label='Calibration', lw=4)
    ax.plot(np.linspace(0, 1, 100), X_inverse_test[sample_id_list[i]*100, 1:-1], label='Ground truth', lw=4)
    ax.set_xlabel('t', fontsize=14)
    ax.set_ylabel('u(t)', fontsize=14)
    ax.set_title(f"{sample_id_list[i]}-th sample")
    ax.legend()
    ax.grid(True)
    ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.savefig('s_prediction_batch.png', bbox_inches='tight', transparent=True)

# %% [markdown]
# #### Inverse calibration: L-BFGS

# %%
def obj_fn(u_var, model, s_target, convert_to_numpy=False):
    """ Calculate objective function.

    Args:
    ----
    u_var: u()
    model: the trained PI-DeepONet model
    s_target: the observed s()
    convert_to_numpy: boolean, indicate whether to convert the calculated objective value to numpy


    Outputs:
    --------
    obj: objective function
    """

    # Initial condition prediction
    y_pred_IC = model({"forcing": u_var, "time": 0})

    # ODE residual
    ODE_residual = ODE_residual_calculator(t=tf.reshape(tf.linspace(0.0, 1.0, 100), (-1, 1)),
                                           u=tf.tile(tf.reshape(u_var, (1, -1)), [100, 1]),
                                           u_t=tf.cast(tf.reshape(u_var, (-1, 1)), tf.float32), model=model)

    # Predict the output with the current inputs
    y_pred = model({"forcing": tf.tile(tf.reshape(u_var, (1, -1)), [100, 1]),
                    "time": tf.reshape(tf.linspace(0.0, 1.0, 100), (-1, 1))})

    # Compute the data loss
    data_loss = tf.reduce_mean(keras.losses.mean_squared_error(s_target, y_pred))

    # Calculate other losses
    IC_loss = tf.reduce_mean(keras.losses.mean_squared_error(0, y_pred_IC))
    ODE_loss = tf.reduce_mean(tf.square(ODE_residual))

    # Obj function
    obj = IC_loss + ODE_loss + data_loss
    obj = obj if not convert_to_numpy else obj.numpy().astype(np.float64)

    return obj

# %%
from scipy.optimize import minimize

# Define the objective function
def obj_fn_numpy(u_var, model, s_target):
    return obj_fn(u_var, model, s_target, convert_to_numpy=True)

def obj_fn_tensor(u_var, model, s_target):
    return obj_fn(u_var, model, s_target, convert_to_numpy=False)

def grad_fn(u, model, s_target):
    u_var = tf.Variable(u, dtype=tf.float32)

    with tf.GradientTape() as tape:
        tape.watch(u_var)
        obj = obj_fn_tensor(u_var, model, s_target)

    # Calculate gradients
    grads = tape.gradient(obj, u_var)

    return grads.numpy().astype(np.float64)


def optimize_u_LBFGS(model, initial_u, s_target, opt_steps=1000):
    """Optimize the inputs to a model to achieve a target output.

    Args:
    ----
    model: the trained PI-DeepONet model
    initial_u: initial guess for u()
    s_target: the observed s()
    opt_steps: number of optimization iterations

    Outputs:
    --------
    res.x: the optimized u
    """

    # L-BFGS optimizer
    res = minimize(fun=obj_fn_numpy, x0=initial_u, args=(model, s_target),
                   method='L-BFGS-B', jac=grad_fn, options={'maxiter': opt_steps, 'disp': True})

    return res.x

# %% [markdown]
# We randomly select one s() profile and see if our approach can identified the correct u() that generated the given s().

# %%
sample_id = 15
initial_u = np.zeros(100, dtype=np.float32)
s_target = y_inverse_test[sample_id*100:(sample_id+1)*100, :]
opt_u_LBFGS = optimize_u_LBFGS(PI_DeepONet, initial_u, s_target, opt_steps=1000)

# %%
# %matplotlib inline
fig, ax = plt.subplots(1, 2, figsize=(8, 3))
ax[0].plot(np.linspace(0, 1, 100), opt_u_LBFGS, label='Calibration', lw=4)
ax[0].plot(np.linspace(0, 1, 100), X_inverse_test[sample_id*100, 1:-1], label='Ground truth', lw=4)
ax[0].set_title('u(t)', fontsize=14)

# Inference pipeline
dataset = np.concatenate([np.linspace(0, 1, 100).reshape(-1, 1), np.tile(opt_u_LBFGS, (100, 1))], axis=1)
pred = PI_DeepONet.predict({"forcing": dataset[:, 1:], "time": dataset[:, :1]}, batch_size=12800)
ax[1].plot(np.linspace(0, 1, 100), pred.flatten(), label='Calibration', lw=4)

# ODE solver
t = np.linspace(0, 1, 100)
sol = solve_ivp(lambda var_t, var_s: a*np.interp(var_t, t, opt_u_LBFGS)+b,
                t_span=[0, 1], y0=[0], t_eval=t, method='RK45')
ax[1].plot(np.linspace(0, 1, 100), sol.y[0], label='ODE Solver', lw=4)

# Ground truth
ax[1].plot(np.linspace(0, 1, 100), s_target.flatten(), label='Ground truth', lw=4)
ax[1].set_title('s(t)', fontsize=14)

for axs in ax:
    axs.legend()
    axs.grid(True)
    axs.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.savefig('s_prediction_L_BFGS.png', bbox_inches='tight', transparent=True)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %% [markdown]
# We further test other u() profiles to see if the approach works properly

# %%
opt_u_list = []
sample_id_list = []
for i in range(6):
    sample_id = np.random.randint(0, 100)
    print(f"Start {i+1} iteration, picked {sample_id}-th sample!")

    initial_u = np.zeros(100, dtype=np.float32)
    s_target = y_inverse_test[sample_id*100:(sample_id+1)*100, :]
    opt_u = optimize_u_LBFGS(PI_DeepONet, initial_u, s_target, opt_steps=1000)
    opt_u_list.append(opt_u)
    sample_id_list.append(sample_id)
# Out:
# Start 1 iteration, picked 84-th sample!
# Start 2 iteration, picked 74-th sample!
# Start 3 iteration, picked 48-th sample!
# Start 4 iteration, picked 89-th sample!
# Start 5 iteration, picked 63-th sample!
# Start 6 iteration, picked 76-th sample!

# %%
# %matplotlib inline
fig, axs = plt.subplots(2, 3, figsize=(13, 6))
for i in range(6):
    ax = axs[i//3, i%3]

    ax.plot(np.linspace(0, 1, 100), opt_u_list[i], label='Calibration', lw=4)
    ax.plot(np.linspace(0, 1, 100), X_inverse_test[sample_id_list[i]*100, 1:-1], label='Ground truth', lw=4)
    ax.set_xlabel('t', fontsize=14)
    ax.set_ylabel('u(t)', fontsize=14)
    ax.set_title(f"{sample_id_list[i]}-th sample")
    ax.legend()
    ax.grid(True)
    ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.savefig('s_prediction_LBFGS_batch.png', bbox_inches='tight', transparent=True)
